# %%
# %load_ext autoreload
# %autoreload 2

# %%
from DATA0 import (
    build_stage2_dataset,
    ClientCardSchemaConfig,
)

cfg = ClientCardSchemaConfig(
    trans_path="../../5DATA/dataset/train_stage1",
    users_path="../../5DATA/original/users_data.csv",
    cards_path="../../5DATA/original/cards_data.csv",
)

stage2_df = build_stage2_dataset(cfg)

stage2_df.shape
# Out:
# /home/nakyung/projects/BDAIFin/5MODEL/STAGE2/_3_SchemaType.py:120: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["has_chip"] = df["has_chip"].replace({"YES": 1, "NO": 0}).astype("int8")
# (608430, 55)

# %%
stage2_df
# Out:
#               id                date  client_id  card_id      amount  \
# 0        7475335 2010-01-01 00:14:00       1684     2140   26.459999
# 1        7475346 2010-01-01 00:34:00        394     4717   26.040001
# 2        7475353 2010-01-01 00:43:00        301     3742   10.170000
# 3        7475359 2010-01-01 00:48:00       1127     3869   22.570000
# 4        7475365 2010-01-01 01:01:00        820      127  270.220001
# ...          ...                 ...        ...      ...         ...
# 609653  17172497 2015-12-31 22:56:00        153      107   42.549999
# 609654  17172534 2015-12-31 23:28:00       1910     4615   35.509998
# 609655  17172536 2015-12-31 23:30:00       1225     5762   38.970001
# 609656  17172537 2015-12-31 23:35:00        737      148   81.879997
# 609657  17172550 2015-12-31 23:47:00       1069     3922   25.850000
#
#         merchant_id   mcc  is_online  fraud  has_error  ...  \
# 0             39021  4784          1      0          0  ...
# 1             39021  4784          1      0          0  ...
# 2             39021  4784          1      0          0  ...
# 3             39021  4784          1      0          0  ...
# 4             73186  4814          1      0          0  ...
# ...             ...   ...        ...    ...        ...  ...
# 609653        76721  6300          1      0          0  ...
# 609654        50404  4784          1      0          0  ...
# 609655        16798  4121          1      0          0  ...
# 609656        73186  4814          1      0          0  ...
# 609657        39021  4784          1      0          0  ...
#
#         years_since_pin_change  years_to_retirement  income_ratio_region  \
# 0                            0                    9             2.038411
# 1                            1                   19             2.038901
# 2                            1                   22             2.038980
# 3                            1                   11             2.038957
# 4                            1                    0             1.565727
# ...                        ...                  ...                  ...
# 609653                       5                    0             1.252118
# 609654                       7                   10             2.039113
# 609655                       6                   16             2.038905
# 609656                       6                    0             1.601129
# 609657                       5                   15             2.039045
#
#         log_yearly_income  log_income_ratio_region  abs_amount  \
# 0               10.235019                 1.111335   26.459999
# 1               11.150592                 1.111496   26.040001
# 2               10.864923                 1.111522   10.170000
# 3               10.479848                 1.111515   22.570000
# 4               10.643113                 0.942242  270.220001
# ...                   ...                      ...         ...
# 609653          10.221395                 0.811871   42.549999
# 609654          10.487629                 1.111566   35.509998
# 609655          11.048315                 1.111497   38.970001
# 609656          10.320881                 0.955945   81.879997
# 609657          10.733196                 1.111543   25.850000
#
#         amount_income_ratio  amount_limit_ratio  log_amount_income_ratio  \
# 0                  0.000950            0.575217                 0.000949
# 1                  0.000374            0.001117                 0.000374
# 2                  0.000194            0.000484                 0.000194
# 3                  0.000634            0.000816                 0.000634
# 4                  0.006449            0.013017                 0.006428
# ...                     ...                 ...                      ...
# 609653             0.001548            0.001326                 0.001547
# 609654             0.000990            0.004147                 0.000990
# 609655             0.000620            0.002527                 0.000620
# 609656             0.002697            0.012061                 0.002693
# 609657             0.000564            0.002938                 0.000564
#
#         log_amount_limit_ratio
# 0                     0.454393
# 1                     0.001116
# 2                     0.000484
# 3                     0.000816
# 4                     0.012933
# ...                        ...
# 609653                0.001325
# 609654                0.004139
# 609655                0.002524
# 609656                0.011989
# 609657                0.002933
#
# [608430 rows x 55 columns]

# %%
stage2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 608430 entries, 0 to 609657
# Data columns (total 55 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        608430 non-null  int64
#  1   date                      608430 non-null  datetime64[ns]
#  2   client_id                 608430 non-null  int64
#  3   card_id                   608430 non-null  int64
#  4   amount                    608430 non-null  float32
#  5   merchant_id               608430 non-null  int64
#  6   mcc                       608430 non-null  object
#  7   is_online                 608430 non-null  int8
#  8   fraud                     608430 non-null  int8
#  9   has_error                 608430 non-null  int8
#  10  err_bad_card_number       608430 non-null  int8
#  11  err_bad_expiration        608430 non-null  int8
#  12  err_bad_cvv               608430 non-null  int8
#  13  err_bad_pin               608430 non-null  int8
#  14  err_bad_zipcode           608430 non-null  int8
#  15  err_insufficient_balance  608430 non-null  int8
#  16  err_technical_glitch      608430 non-null  int8
#  17  tx_year                   608430 non-null  int16
#  18  tx_month                  608430 non-null  int8
#  19  tx_day                    608430 non-null  int8
#  20  tx_hour                   608430 non-null  int8
#  21  weekday                   608430 non-null  int8
#  22  is_refund                 608430 non-null  int8
#  23  log_abs_amount            608430 non-null  float32
#  24  current_age               608430 non-null  int64
#  25  per_capita_income         608430 non-null  float32
#  26  yearly_income             608430 non-null  float32
#  27  total_debt                608430 non-null  float32
#  28  credit_score              608430 non-null  int64
#  29  num_credit_cards          608430 non-null  int8
#  30  has_chip                  608430 non-null  int8
#  31  num_cards_issued          608430 non-null  int64
#  32  credit_limit              608430 non-null  float32
#  33  year_pin_last_changed     608430 non-null  Int16
#  34  expires_year              608430 non-null  int16
#  35  expires_month             608430 non-null  int8
#  36  months_to_expire          608430 non-null  int16
#  37  is_credit                 608430 non-null  int8
#  38  is_prepaid                608430 non-null  int8
#  39  male                      608430 non-null  int8
#  40  cb_Visa                   608430 non-null  int8
#  41  cb_Mastercard             608430 non-null  int8
#  42  cb_Amex                   608430 non-null  int8
#  43  cb_Discover               608430 non-null  int8
#  44  months_from_account       608430 non-null  int16
#  45  years_since_pin_change    608430 non-null  int8
#  46  years_to_retirement       608430 non-null  int16
#  47  income_ratio_region       608430 non-null  float32
#  48  log_yearly_income         608430 non-null  float32
#  49  log_income_ratio_region   608430 non-null  float32
#  50  abs_amount                608430 non-null  float32
#  51  amount_income_ratio       608430 non-null  float32
#  52  amount_limit_ratio        608430 non-null  float32
#  53  log_amount_income_ratio   608430 non-null  float32
#  54  log_amount_limit_ratio    608430 non-null  float32
# dtypes: Int16(1), datetime64[ns](1), float32(14), int16(5), int64(7), int8(26), object(1)
# memory usage: 101.5+ MB

# %%
stage2_df.to_parquet("../../5DATA/dataset/train_stage2")

# %%
stage2_df.isnull().sum()
# Out:
# id                          0
# date                        0
# client_id                   0
# card_id                     0
# amount                      0
# merchant_id                 0
# mcc                         0
# is_online                   0
# fraud                       0
# has_error                   0
# err_bad_card_number         0
# err_bad_expiration          0
# err_bad_cvv                 0
# err_bad_pin                 0
# err_bad_zipcode             0
# err_insufficient_balance    0
# err_technical_glitch        0
# tx_year                     0
# tx_month                    0
# tx_day                      0
# tx_hour                     0
# weekday                     0
# is_refund                   0
# log_abs_amount              0
# current_age                 0
# per_capita_income           0
# yearly_income               0
# total_debt                  0
# credit_score                0
# num_credit_cards            0
# has_chip                    0
# num_cards_issued            0
# credit_limit                0
# year_pin_last_changed       0
# expires_year                0
# expires_month               0
# months_to_expire            0
# is_credit                   0
# is_prepaid                  0
# male                        0
# cb_Visa                     0
# cb_Mastercard               0
# cb_Amex                     0
# cb_Discover                 0
# months_from_account         0
# years_since_pin_change      0
# years_to_retirement         0
# income_ratio_region         0
# log_yearly_income           0
# log_income_ratio_region     0
# abs_amount                  0
# amount_income_ratio         0
# amount_limit_ratio          0
# log_amount_income_ratio     0
# log_amount_limit_ratio      0
# dtype: int64

# %%
from _3_SchemaType import (
    build_stage2_dataset,
    ClientCardSchemaConfig,
)

cfg = ClientCardSchemaConfig(
    trans_path="../../5DATA/dataset/test_stage1",
    users_path="../../5DATA/original/users_data.csv",
    cards_path="../../5DATA/original/cards_data.csv",
)

stage2_df = build_stage2_dataset(cfg)

stage2_df.shape
# Out:
# /home/nakyung/projects/BDAIFin/5MODEL/STAGE2/_3_SchemaType.py:120: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["has_chip"] = df["has_chip"].replace({"YES": 1, "NO": 0}).astype("int8")
# (113943, 55)

# %%
stage2_df.to_parquet("../../5DATA/dataset/test_stage2")
