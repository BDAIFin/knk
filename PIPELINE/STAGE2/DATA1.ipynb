# %%
# %load_ext autoreload
# %autoreload 2

import PIPELINE.STAGE2.DATA1 as DATA1

DATA1.build_train_stage2()
# Out:
# saved: ../../DATA/dataset/TRAIN_stage2
# shape: (608430, 24)
# n_features: 22
# mem(MB): 38.88
# stage1_added_cols: 10
# stage2_cols: 12

# %%
# 결과 확인
import pandas as pd

df_train2 = pd.read_parquet("../../DATA/dataset/TRAIN_stage2")
print(df_train2.shape)
print(df_train2.columns.tolist())
df_train2.head()
# Out:
# (608430, 24)
# ['id', 'fraud', 'card_fraud_last3', 'client_error_last3', 'client_mcc_is_new', 'vel_x_merchant_new', 'vel_x_mcc_risk', 'amount_limit_ratio', 'limit_ratio_extreme', 'merchant_change_last5_x_amount_limit_ratio', 'log_interval_dev', 'seconds_since_prev_tx', 'credit_limit', 'is_refund', 'mcc_smoothed_risk', 'mcc_risk_level', 'hour_sin', 'hour_cos', 'weekday', 'month_sin', 'is_risky_wd_hour', 'is_risky_month', 'log_abs_amount', 'err_bad_cvv']
#         id  fraud  card_fraud_last3  client_error_last3  client_mcc_is_new  \
# 0  7487951      0                 0                   0                  1
# 1  7516735      0                 0                   0                  1
# 2  7529000      0                 0                   0                  1
# 3  7564511      0                 0                   0                  0
# 4  7630887      0                 0                   0                  0
#
#    vel_x_merchant_new  vel_x_mcc_risk  amount_limit_ratio  \
# ...
