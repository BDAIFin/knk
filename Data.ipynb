# %%
import pandas as pd
data = pd.read_parquet("data/online/train_oss.parquet")
data.columns
# Out:
# Index(['client_id', 'card_id', 'amount', 'merchant_id', 'current_age',
#        'retirement_age', 'birth_year', 'birth_month', 'latitude', 'longitude',
#        'per_capita_income', 'yearly_income', 'total_debt', 'credit_score',
#        'num_credit_cards', 'has_chip', 'num_cards_issued', 'credit_limit',
#        'year_pin_last_changed', 'is_online', 'has_error',
#        'err_bad_card_number', 'err_bad_expiration', 'err_bad_cvv',
#        'err_bad_pin', 'err_bad_zipcode', 'err_insufficient_balance',
#        'err_technical_glitch', 'acct_open_year', 'acct_open_month',
#        'expires_year', 'expires_month', 'months_to_expire', 'tx_year',
#        'tx_month', 'tx_hour', 'is_weekend', 'is_credit', 'is_prepaid', 'male',
#        'mccg_Food_Daily', 'mccg_Transport_Travel', 'mccg_Digital_Online',
#        'mccg_Financial', 'mccg_Retail', 'mccg_Medical', 'mccg_Entertainment',
#        'mccg_Automotive_Home', 'mccg_Utilities_Government',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708107 entries, 0 to 708106
# Data columns (total 57 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   client_id                        708107 non-null  int64
#  1   card_id                          708107 non-null  int64
#  2   amount                           708107 non-null  float32
#  3   merchant_id                      708107 non-null  int64
#  4   current_age                      708107 non-null  int64
#  5   retirement_age                   708107 non-null  int64
#  6   birth_year                       708107 non-null  int64
#  7   birth_month                      708107 non-null  int8
#  8   latitude                         708107 non-null  float64
#  9   longitude                        708107 non-null  float64
#  10  per_capita_income                708107 non-null  float32
# ...

# %%
data["is_online"].unique()
# Out:
# array([1], dtype=int8)

# %%
data
# Out:
#         client_id  card_id      amount  ...  cb_Discover  distance_imputed  fraud
# 0             335     5131   87.830002  ...            0                 0      1
# 1             379     2019   23.100000  ...            0                 0      1
# 2            1048     2542   95.919998  ...            0                 0      1
# 3            1019     5112  421.559998  ...            0                 0      1
# 4             720     4136   38.369999  ...            0                 0      1
# ...           ...      ...         ...  ...          ...               ...    ...
# 708102        877     3877    7.700000  ...            0                 0      0
# 708103       1341     4766   28.049999  ...            0                 0      0
# 708104        987     2748   25.250000  ...            0                 0      0
# 708105        585     5881   21.410000  ...            0                 0      0
# ...
