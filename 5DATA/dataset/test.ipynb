# %%
import pandas as pd
df = pd.read_parquet("test_stage2")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113943 entries, 0 to 114208
# Data columns (total 55 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        113943 non-null  int64
#  1   date                      113943 non-null  datetime64[ns]
#  2   client_id                 113943 non-null  int64
#  3   card_id                   113943 non-null  int64
#  4   amount                    113943 non-null  float32
#  5   merchant_id               113943 non-null  int64
#  6   mcc                       113943 non-null  object
#  7   is_online                 113943 non-null  int8
#  8   fraud                     113943 non-null  int8
#  9   has_error                 113943 non-null  int8
#  10  err_bad_card_number       113943 non-null  int8
#  11  err_bad_expiration        113943 non-null  int8
#  12  err_bad_cvv               113943 non-null  int8
# ...

# %%
import pandas as pd
df = pd.read_parquet("TEST_stage2")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928867 entries, 0 to 928866
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           928867 non-null  int64
#  1   card_fraud_last3             928867 non-null  int8
#  2   client_fraud_last3           928867 non-null  int8
#  3   amount_deviation             928867 non-null  float32
#  4   client_merchant_is_new       928867 non-null  int8
#  5   card_merchant_is_new         928867 non-null  int8
#  6   mccnew_x_velocity            928867 non-null  float32
#  7   dev_x_mccnew                 928867 non-null  float32
#  8   client_mcc_repeat_cnt_last5  928867 non-null  int8
#  9   card_mcc_change_cnt_last5    928867 non-null  int8
#  10  merchant_change_cnt_last5    928867 non-null  int8
#  11  client_tx_1h_avg_prev        928867 non-null  float32
# ...

# %%
import pandas as pd
df = pd.read_parquet("train_stage1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 609658 entries, 0 to 609657
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        609658 non-null  int64
#  1   date                      609658 non-null  datetime64[ns]
#  2   client_id                 609658 non-null  int64
#  3   card_id                   609658 non-null  int64
#  4   amount                    609658 non-null  float32
#  5   merchant_id               609658 non-null  int64
#  6   mcc                       609658 non-null  object
#  7   is_online                 609658 non-null  int8
#  8   fraud                     609658 non-null  int8
#  9   has_error                 609658 non-null  int8
#  10  err_bad_card_number       609658 non-null  int8
#  11  err_bad_expiration        609658 non-null  int8
#  12  err_bad_cvv               609658 non-null  int8
# ...

# %%
df["fraud"].value_counts()
# Out:
# fraud
# 0    603060
# 1      6598
# Name: count, dtype: int64

# %%
df = pd.read_parquet("test_stage1")
df["fraud"].value_counts()
# Out:
# fraud
# 0    112113
# 1      2096
# Name: count, dtype: int64

# %%
import pandas as pd
df = pd.read_parquet("TRAIN_stage1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 609658 entries, 0 to 609657
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           609658 non-null  int64
#  1   fraud                        609658 non-null  int8
#  2   log_abs_amount               609658 non-null  float32
#  3   high_amount                  609658 non-null  int8
#  4   amount_vs_client_avg_diff    609658 non-null  float32
#  5   amount_deviation             609658 non-null  float32
#  6   has_error                    609658 non-null  int8
#  7   err_bad_cvv                  609658 non-null  int8
#  8   err_bad_card_number          609658 non-null  int8
#  9   err_bad_expiration           609658 non-null  int8
#  10  card_error_last1             609658 non-null  int8
#  11  client_error_last1           609658 non-null  int8
#  12  card_fraud_last1             609658 non-null  int8
# ...

# %%
df = pd.read_parquet("CHECK_stage2")
df
# Out:
#                id  card_fraud_last3  client_fraud_last3  amount_deviation  \
# 0        18881490                 0                   0          0.791681
# 1        18881494                 0                   0         -0.794006
# 2        18881495                 0                   0          0.208574
# 3        18881497                 0                   0          1.539824
# 4        18881498                 0                   0          1.502129
# ...           ...               ...                 ...               ...
# 1375867  21421691                 0                   0          0.056700
# 1375868  21421693                 0                   0         -0.548915
# 1375869  21421689                 0                   0          0.289487
# 1375870  21421690                 0                   0         -0.440716
# 1375871  21421698                 0                   0          0.958220
#
#          client_merchant_is_new  card_merchant_is_new  mccnew_x_velocity  \
# ...

# %%
df["fraud"].value_counts()
# Out:
# fraud
# 0    1374989
# 1        883
# Name: count, dtype: int64

# %%
import pandas as pd
data = pd.read_csv("../original/transactions_data.csv")

# %%
data.shape
# Out:
# (11413790, 12)

# %%
df = pd.read_parquet("TEST_stage1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114209 entries, 0 to 114208
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           114209 non-null  int64
#  1   fraud                        114209 non-null  int8
#  2   log_abs_amount               114209 non-null  float32
#  3   high_amount                  114209 non-null  int8
#  4   amount_vs_client_avg_diff    114209 non-null  float32
#  5   amount_deviation             114209 non-null  float32
#  6   has_error                    114209 non-null  int8
#  7   err_bad_cvv                  114209 non-null  int8
#  8   err_bad_card_number          114209 non-null  int8
#  9   err_bad_expiration           114209 non-null  int8
#  10  card_error_last1             114209 non-null  int8
#  11  client_error_last1           114209 non-null  int8
#  12  card_fraud_last1             114209 non-null  int8
# ...
