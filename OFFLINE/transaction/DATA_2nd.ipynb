# %%
pwd
# Out:
# '/home/nakyung/projects/BDAIFin/OFFLINE/transaction'

# %%
import sys
from pathlib import Path
import pandas as pd
from ServingColumns import (
    fit_stage1_artifacts,
    build_stage1_features,
    save_json
)

# %%
TRAIN_IN = Path("../../DATA/dataset/train_stage1")
TEST_IN  = Path("../../DATA/dataset/test_stage1")

ART_PATH = Path("../../DATA/artifacts/stage1_artifacts.json")

# 출력(원본 덮어쓰기 싫으면 _final 같은 이름 추천)
TRAIN_OUT = Path("../../DATA/dataset/TRAIN_stage1")
TEST_OUT  = Path("../../DATA/dataset/TEST_stage1")

print("TRAIN_IN:", TRAIN_IN.resolve())
print("TEST_IN :", TEST_IN.resolve())
# Out:
# TRAIN_IN: /home/nakyung/projects/BDAIFin/DATA/dataset/train_stage1
# TEST_IN : /home/nakyung/projects/BDAIFin/DATA/dataset/test_stage1

# %%
df_train_raw = pd.read_parquet(TRAIN_IN)
df_test_raw  = pd.read_parquet(TEST_IN)

print("raw train:", df_train_raw.shape, "| cols:", len(df_train_raw.columns))
print("raw test :", df_test_raw.shape,  "| cols:", len(df_test_raw.columns))
# Out:
# raw train: (5332979, 23) | cols: 23
# raw test : (932762, 23) | cols: 23

# %%
artifacts = fit_stage1_artifacts(df_train_raw) 

ART_PATH.parent.mkdir(parents=True, exist_ok=True)
save_json(artifacts, str(ART_PATH))

print("saved artifacts:", ART_PATH)
print("base_rate:", artifacts["base_rate"])
print("highrisk_mcc:", len(artifacts["highrisk_mcc"]))
# Out:
# saved artifacts: ../../DATA/artifacts/stage1_artifacts.json
# base_rate: 0.0014481587120444314
# highrisk_mcc: 44

# %%
df_train_s1 = build_stage1_features(df_train_raw, artifacts)
df_test_s1  = build_stage1_features(df_test_raw, artifacts)

# (선택) train/test 컬럼 일치 확인
assert list(df_train_s1.columns) == list(df_test_s1.columns), "train/test stage1 columns mismatch!"

TRAIN_OUT.parent.mkdir(parents=True, exist_ok=True)
df_train_s1.to_parquet(TRAIN_OUT, index=False)
df_test_s1.to_parquet(TEST_OUT, index=False)

print("saved:", TRAIN_OUT, "| shape:", df_train_s1.shape)
print("saved:", TEST_OUT,  "| shape:", df_test_s1.shape)
# Out:
# saved: ../../DATA/dataset/TRAIN_stage1.parquet | shape: (5332979, 16)
# saved: ../../DATA/dataset/TEST_stage1.parquet | shape: (932762, 16)
