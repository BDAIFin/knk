# %%
import importlib
import _4_ServingColumns
importlib.reload(_4_ServingColumns)
# Out:
# <module '_4_ServingColumns' from '/home/nakyung/projects/BDAIFin/5MODEL/STAGE2/_4_ServingColumns.py'>

# %%
pwd
# Out:
# '/home/nakyung/projects/BDAIFin/5MODEL/STAGE2'

# %%
from pathlib import Path

base = Path("../../5DATA/dataset")
print("abs path:", base.resolve())
print("exists:", base.exists())
print("contents:")
for p in base.iterdir():
    print(" -", p.name)
# Out:
# abs path: /home/nakyung/projects/BDAIFin/5DATA/dataset
# exists: True
# contents:
#  - train_stage2
#  - TRAIN_stage1
#  - TEST_stage2
#  - test_stage1
#  - TRAIN_stage2
#  - CHECK_stage2
#  - train_stage1
#  - test.ipynb
#  - test_stage2
#  - check_stage1
#  - TEST_stage1
#  - check_stage2

# %%
from pathlib import Path
import pandas as pd

# 현재 노트북 위치 기준으로 "BDAIFin" 루트 자동 탐색(안전)
HERE = Path.cwd()
# /home/nakyung/projects/BDAIFin/5MODEL/STAGE2 같은 경로라면
ROOT = HERE
while ROOT.name != "BDAIFin" and ROOT != ROOT.parent:
    ROOT = ROOT.parent

if ROOT.name != "BDAIFin":
    raise RuntimeError(f"Cannot find BDAIFin root from cwd={HERE}")

DATA_ROOT = ROOT / "5DATA"

TRAIN_IN  = DATA_ROOT / "dataset" / "train_stage2"
TEST_IN   = DATA_ROOT / "dataset" / "test_stage2"
ART_PATH  = DATA_ROOT / "artifacts" / "stage2_artifacts.json"
MCC_STATS_PATH = DATA_ROOT / "artifacts" / "mcc_stats.parquet"

TRAIN_OUT = DATA_ROOT / "dataset" / "TRAIN_stage2_feat101"
TEST_OUT  = DATA_ROOT / "dataset" / "TEST_stage2_feat101"

print("ROOT:", ROOT)
print("TRAIN_IN exists:", TRAIN_IN.exists(), "is_dir:", TRAIN_IN.is_dir())
print("TEST_IN  exists:", TEST_IN.exists(),  "is_dir:", TEST_IN.is_dir())
# Out:
# ROOT: /home/nakyung/projects/BDAIFin
# TRAIN_IN exists: True is_dir: False
# TEST_IN  exists: True is_dir: False

# %%
from _4_ServingColumns import fit_artifacts, build_features_101, save_json, sanity_report
print("Imported OK:", fit_artifacts, build_features_101)
# Out:
# Imported OK: <function fit_artifacts at 0x7f19f19bd000> <function build_features_101 at 0x7f19f19bcb80>

# %%
from pathlib import Path
import pandas as pd
import shutil

TRAIN_IN  = "../../5DATA/dataset/train_stage2"
TEST_IN   = "../../5DATA/dataset/test_stage2"

ART_PATH  = "../../5DATA/artifacts/stage2_artifacts.json"
MCC_STATS_PATH = "../../5DATA/artifacts/mcc_stats.parquet"

TRAIN_OUT = "../../5DATA/dataset/TRAIN_stage2"
TEST_OUT  = "../../5DATA/dataset/TEST_stage2"

# read (폴더 parquet dataset)
df_train_raw = pd.read_parquet(TRAIN_IN)
df_test_raw  = pd.read_parquet(TEST_IN)

print("train raw:", df_train_raw.shape)
print("test  raw :", df_test_raw.shape)

# artifacts (train only)
artifacts, mcc_stats_df = fit_artifacts(df_train_raw)
save_json(artifacts, ART_PATH)
Path(MCC_STATS_PATH).parent.mkdir(parents=True, exist_ok=True)
mcc_stats_df.to_parquet(MCC_STATS_PATH, index=False)

print("saved artifacts:", ART_PATH)
print("saved mcc_stats:", MCC_STATS_PATH)

# build features
df_train_feat = build_features_101(df_train_raw, artifacts, mcc_stats_df)
df_test_feat  = build_features_101(df_test_raw,  artifacts, mcc_stats_df)

print("train feat:", df_train_feat.shape)
print("test  feat :", df_test_feat.shape)

sanity_report(df_train_feat)
sanity_report(df_test_feat)

# overwrite-safe save
for out in [TRAIN_OUT, TEST_OUT]:
    p = Path(out)
    if p.exists():
        shutil.rmtree(p)

df_train_feat.to_parquet(TRAIN_OUT, index=False)
df_test_feat.to_parquet(TEST_OUT, index=False)

print("saved TRAIN_OUT:", TRAIN_OUT)
print("saved TEST_OUT :", TEST_OUT)
# Out:
# train raw: (608430, 55)
# test  raw : (113943, 55)
# saved artifacts: ../../5DATA/artifacts/stage2_artifacts.json
# saved mcc_stats: ../../5DATA/artifacts/mcc_stats.parquet
# train feat: (608430, 100)
# test  feat : (113943, 100)
# === Sanity Check ===
# n_features: 98
# missing: []
# extra: []
# === Sanity Check ===
# n_features: 98
# missing: []
# extra: []
# saved TRAIN_OUT: ../../5DATA/dataset/TRAIN_stage2
# saved TEST_OUT : ../../5DATA/dataset/TEST_stage2

# %%
t = pd.read_parquet("../../5DATA/dataset/TRAIN_stage2")
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608430 entries, 0 to 608429
# Data columns (total 100 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   id                                          608430 non-null  int32
#  1   refund_high_amount                          608430 non-null  int8
#  2   log_abs_amount                              608430 non-null  float32
#  3   err_bad_cvv                                 608430 non-null  int8
#  4   card_hist_x_error                           608430 non-null  int8
#  5   client_hist_x_error                         608430 non-null  int8
#  6   err_bad_card_number                         608430 non-null  int8
#  7   err_insufficient_balance                    608430 non-null  int8
#  8   client_error_last5                          608430 non-null  int8
#  9   card_error_last5                            608430 non-null  int8
#  10  client_error_last3                          608430 non-null  int8
#  11  card_error_last3                            608430 non-null  int8
#  12  client_error_last1                          608430 non-null  int8
#  13  card_error_last1                            608430 non-null  int8
#  14  hour_cos                                    608430 non-null  float32
#  15  hour_sin                                    608430 non-null  float32
#  16  tx_hour                                     608430 non-null  int8
#  17  weekday                                     608430 non-null  int8
#  18  tx_month                                    608430 non-null  int8
#  19  tx_year                                     608430 non-null  int16
#  20  tx_day                                      608430 non-null  int8
#  21  client_weekday_match_last1                  608430 non-null  int8
#  22  cos_shift                                   608430 non-null  float32
#  23  sin_shift                                   608430 non-null  float32
#  24  client_weekday_prev                         608430 non-null  float32
#  25  cnt_past                                    608430 non-null  int16
#  26  client_cos_mean_past                        608430 non-null  float32
#  27  client_sin_mean_past                        608430 non-null  float32
#  28  client_weekday_prior_count                  608430 non-null  int16
#  29  log_yearly_income                           608430 non-null  float32
#  30  credit_limit                                608430 non-null  float32
#  31  num_credit_cards                            608430 non-null  int8
#  32  log_income_ratio_region                     608430 non-null  float32
#  33  credit_score                                608430 non-null  int16
#  34  current_age                                 608430 non-null  int8
#  35  years_to_retirement                         608430 non-null  int8
#  36  months_from_account                         608430 non-null  int16
#  37  total_debt                                  608430 non-null  float32
#  38  per_capita_income                           608430 non-null  float32
#  39  yearly_income                               608430 non-null  float32
#  40  income_ratio_region                         608430 non-null  float32
#  41  cb_Visa                                     608430 non-null  int8
#  42  cb_Discover                                 608430 non-null  int8
#  43  cb_Mastercard                               608430 non-null  int8
#  44  is_prepaid                                  608430 non-null  int8
#  45  discover_x_cvv                              608430 non-null  int8
#  46  prepaid_logamount_interaction               608430 non-null  float32
#  47  cb_Amex                                     608430 non-null  int8
#  48  mcc_smoothed_risk                           608430 non-null  float32
#  49  mcc_risk_level                              608430 non-null  int8
#  50  is_highrisk_weekday                         608430 non-null  int8
#  51  high_mcc_high_weekday                       608430 non-null  int8
#  52  merchant_is_new_x_has_error                 608430 non-null  int8
#  53  merchant_is_new_x_mcc_is_new                608430 non-null  int8
#  54  merchant_change_cnt_last5                   608430 non-null  int8
#  55  card_merchant_is_new                        608430 non-null  int8
#  56  client_merchant_is_new                      608430 non-null  int8
#  57  seconds_since_prev_tx                       608430 non-null  float32
#  58  client_avg_interval_prev                    608430 non-null  float32
#  59  log_interval_dev                            608430 non-null  float32
#  60  client_tx_1h                                608430 non-null  int8
#  61  client_tx_1h_avg_prev                       608430 non-null  float32
#  62  velocity_spike_ratio                        608430 non-null  float32
#  63  card_tx_1h                                  608430 non-null  int8
#  64  card_velocity_spike_ratio                   608430 non-null  float32
#  65  vel_x_error                                 608430 non-null  float32
#  66  vel_x_mcc_risk                              608430 non-null  float32
#  67  vel_x_high_mcc                              608430 non-null  float32
#  68  vel_x_merchant_new                          608430 non-null  float32
#  69  vel_x_client_mcc_new                        608430 non-null  float32
#  70  vel_x_card_mcc_new                          608430 non-null  float32
#  71  high_vel_flag                               608430 non-null  int8
#  72  high_vel_error                              608430 non-null  int8
#  73  high_vel_new_mcc                            608430 non-null  int8
#  74  amount_vs_client_avg_ratio                  608430 non-null  float32
#  75  amount_vs_client_avg_diff                   608430 non-null  float32
#  76  amount_vs_recent_window_avg                 608430 non-null  float32
#  77  amount_vs_client_quantile_q95               608430 non-null  float32
#  78  amount_vs_client_quantile_q99               608430 non-null  float32
#  79  amt_over_q95                                608430 non-null  int8
#  80  amt_over_q99                                608430 non-null  int8
#  81  client_fraud_last1                          608430 non-null  int8
#  82  client_fraud_last3                          608430 non-null  int8
#  83  card_fraud_last1                            608430 non-null  int8
#  84  card_fraud_last3                            608430 non-null  int8
#  85  amount_income_ratio                         608430 non-null  float32
#  86  amount_limit_ratio                          608430 non-null  float32
#  87  has_error                                   608430 non-null  int8
#  88  is_credit                                   608430 non-null  int8
#  89  has_chip                                    608430 non-null  int8
#  90  amount_ratio_x_mcc_smoothed_risk            608430 non-null  float32
#  91  client_merchant_is_new_x_mcc_smoothed_risk  608430 non-null  float32
#  92  amount_ratio_x_client_merchant_new          608430 non-null  float32
#  93  card_fraud_last3_x_client_merchant_new      608430 non-null  int8
#  94  client_fraud_last3_x_client_merchant_new    608430 non-null  int8
#  95  client_mcc_is_new_x_mcc_smoothed_risk       608430 non-null  float32
#  96  client_merchant_is_new_x_log_interval_dev   608430 non-null  float32
#  97  amount_ratio_x_client_mcc_new               608430 non-null  float32
#  98  client_mcc_is_new_x_log_interval_dev        608430 non-null  float32
#  99  fraud                                       608430 non-null  int8
# dtypes: float32(43), int16(5), int32(1), int8(51)
# memory usage: 137.5 MB
