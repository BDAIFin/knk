# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path


from _3_SchemaType import (
    build_transaction_schema,
    TransactionSchemaConfig,
)

# %%
TRANS_PATH = "../../5DATA/original/train"
LABEL_PATH = "../../5DATA/original/train_fraud_labels.json"

# %%
cfg = TransactionSchemaConfig()

trans = build_transaction_schema(
    trans_parquet_path=TRANS_PATH,
    labels_json_path=LABEL_PATH,
    cfg=cfg,
)

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 609658 entries, 0 to 609657
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        609658 non-null  int64
#  1   date                      609658 non-null  datetime64[ns]
#  2   client_id                 609658 non-null  int64
#  3   card_id                   609658 non-null  int64
#  4   amount                    609658 non-null  float32
#  5   merchant_id               609658 non-null  int64
#  6   mcc                       609658 non-null  object
#  7   is_online                 609658 non-null  int8
#  8   fraud                     609658 non-null  int8
#  9   has_error                 609658 non-null  int8
#  10  err_bad_card_number       609658 non-null  int8
#  11  err_bad_expiration        609658 non-null  int8
#  12  err_bad_cvv               609658 non-null  int8
# ...

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 609658 entries, 0 to 609657
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        609658 non-null  int64
#  1   date                      609658 non-null  datetime64[ns]
#  2   client_id                 609658 non-null  int64
#  3   card_id                   609658 non-null  int64
#  4   amount                    609658 non-null  float32
#  5   merchant_id               609658 non-null  int64
#  6   mcc                       609658 non-null  object
#  7   is_online                 609658 non-null  int8
#  8   fraud                     609658 non-null  int8
#  9   has_error                 609658 non-null  int8
#  10  err_bad_card_number       609658 non-null  int8
#  11  err_bad_expiration        609658 non-null  int8
#  12  err_bad_cvv               609658 non-null  int8
# ...

# %%
trans.to_parquet("../../5DATA/dataset/train_stage1")

# %% [markdown]
# ---

# %%
TRANS_PATH = "../../5DATA/original/test"
LABEL_PATH = "../../5DATA/original/train_fraud_labels.json"

# %%
cfg = TransactionSchemaConfig()

trans = build_transaction_schema(
    trans_parquet_path=TRANS_PATH,
    labels_json_path=LABEL_PATH,
    cfg=cfg,
)

# %%
trans.to_parquet("../../5DATA/dataset/test_stage1")

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114209 entries, 0 to 114208
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        114209 non-null  int64
#  1   date                      114209 non-null  datetime64[ns]
#  2   client_id                 114209 non-null  int64
#  3   card_id                   114209 non-null  int64
#  4   amount                    114209 non-null  float32
#  5   merchant_id               114209 non-null  int64
#  6   mcc                       114209 non-null  object
#  7   is_online                 114209 non-null  int8
#  8   fraud                     114209 non-null  int8
#  9   has_error                 114209 non-null  int8
#  10  err_bad_card_number       114209 non-null  int8
#  11  err_bad_expiration        114209 non-null  int8
#  12  err_bad_cvv               114209 non-null  int8
# ...
